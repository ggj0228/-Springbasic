# %% [markdown]
# <a href="https://colab.research.google.com/github/ggj0228/-Springbasic/blob/main/practiceMath.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import *

x = symbols('x')
f = 2*x +1
plot(f)

# %%
from sympy import *

x = symbols('x')
f = x **2 + 1
plot(f)

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2 * x + 3 * y
plot3d(f)

# %%
# 합계 수행하기

summation = sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30

# %%
# 네 배열의 합계 구하기

x = [1,4,6,2]
n = len(x)

summation = sum(10*x[i] for i in range(0,n))
print(summation)
# Out:
# 130

# %%
# 파이썬에서 로그 함수 사용하기

from math import log

# 2를 거듭제곱해 8이 되는 지수는?
x =log(8,2)

print(x)
# Out:
# 3.0

# %%
# 복리 이자 계산하기
from math import exp

p = 100 # 시작 투자금
r = 0.20 # 이자율
t = 2.0 # 기간
n = 12 # 연간 복리 적용횟수

a = p * (1 + (r/n)) ** (n*t)

print(a)
# Out:
# 148.69146179463576

# %%
# 연속 이자 계산받기

from math import exp
p = 100 # 시작 투자금
r = 0.20 # 이자율
t = 2.0 # 기간

a = p * exp(r*t)
print(a)
# Out:
# 149.18246976412703

# %%
# 10의 자연로그 계산하기

from math import log

# e를 거듭제곱해 10이 되는 지수는?
x = log(10)

print(x)
# Out:
# 2.302585092994046

# %%
# 심파이로 극한 계산하기

from sympy import *

x = symbols('x')
f = 1 / x
result = limit(f, x, oo)

print(result)
plot(f)
# Out:
# 0

# %%
# 미분 계산하기

def derivative_x(f, x, step_size):
    m = (f(x + step_size) - f(x)) / ((x + step_size) - x)
    return m

def my_function(x):
    return x**2

slope_at_2 = derivative_x(my_function, 2, 0.00001)

print(slope_at_2)
# Out:
# 4.000010000000827

# %%
# 심파이에서 도함수 계산하기

from sympy import *

# 'x'를 선언합니다
x = symbols('x')

# 파이썬 표현식을 사용해 함수를 정의합니다.
f = x ** 2

# 이 함수의 도함수를 계산합니다.
dx_f = diff(f)
print(dx_f)
# Out:
# 2*x

# %%
# 파이썬 미분 계산기

def f(x):
    return x ** 2
def d_f(x):
    return 2 * x

slope_at_2 = d_f(2.0)
print(slope_at_2)
# Out:
# 4.0

# %%
# 심파이의 치환 기능 사용하기
# x = 2에서 기울기 계산하기
print(dx_f.subs(x,2))
# Out:
# 4

# %%
# 심파이로 편도함수 계산하기

from sympy import *
from sympy.plotting import plot3d

# x 와 7를 심파이에 선언합니다.
x,y = symbols('x y')

# 파이썬 표현식을 사용해 함수를 정의합니다.
f = 2*x**3 + 3*y**3

# x와 y에 대한 편도함수를 계산합니다.
dx_f = diff(f,x)
dx_y = diff(f,y)

print(dx_f)
print(dx_y)

plot3d(f)
# Out:
# 6*x**2
# 9*y**2

# %%
# 극한을 사용한 기울기 계산

# 'x'와 스텝 크기 's' 정의
x, s = symbols('x s')

# 함수 정의
f = x ** 2

# 간격 's'만큼 떨어진 두 점을 기울기 공식에 대입합니다.
slope_f = (f.subs(x, x+s) - f) / ((x + s) - x)

#  x에 2를 대입합니다.
slope_2 = slope_f.subs(x,2)

# 스텝 크기 s가 0에 무한히 가까워질 떄 x = 2에서 기울기를 계산합니다.
result = limit(slope_2, s, 0)

print(result)
# Out:
# 4

# %%
# 극한을 사용해 도함수 계산하기

from sympy import *

# 'x'와 스텝 크기 's' 정의
x, s = symbols('x s')

# 함수 정의
f = x ** 2

# 간격 's'만큼 떨어진 두 점을 기울기 공식에 대입합니다.
slope_f = (f.subs(x, x+s) - f) / ((x + s) - x)

# 스텝 크기 s가 0에 무한히 가까워질 때 도함수를 계산합니다.
result = limit(slope_f, s, 0)

print(result)
# Out:
# 2*x

# %%
# x에 대한 z의 도함수 구하기

from sympy import *

x = symbols('x')
z=(x**2 + 1)**3 - 2
dz_dx = diff(z,x)

print(dz_dx)
# Out:
# 6*x*(x**2 + 1)**2

# %%
# 연쇄 법틱 적용 유무에 상관없이 dz/dx 도함수의 계산 결과는 같음

from sympy import *

x, y = symbols('x y')

# 첫 번째 함수의 도함수
# 충돌을 피하기 위해 _y로 씁니다.
_y = x**2 + 1
dy_dx = diff(_y)

# 두 번째 도함수
z = y**3 -2
dz_dy = diff(z)

# 연쇄 법칙을 사용한 경우와
# 대체 방식을 사용한 경우 도함수 계산
dz_dx_chain = (dy_dx * dz_dy).subs(y, _y)
dz_dx_no_chain = diff(z.subs(y, _y))

print(dz_dx_chain)
print(dz_dx_no_chain)
# Out:
# 6*x*(x**2 + 1)**2
# 6*x*(x**2 + 1)**2

# %%
# 파이썬으로 적분 근사하기

def approximate_integral(a, b, n, f):
    delta_x = (b - a) / n
    total_sum = 0

    for i in range(1, n+1):
        midpoint = 0.5 * (2 * a + delta_x * (2 * i -1))
        total_sum += f(midpoint)

    return total_sum * delta_x

def my_function(x):
    return x**2 + 1

area = approximate_integral(a=0, b=1, n=5, f=my_function)
print(area) # 1.33
area = approximate_integral(a=0, b=1, n=1000, f=my_function)
print(area) # 1.333333250000001
area = approximate_integral(a=0, b=1, n=1_000_000, f=my_function)
print(area) # 1.3333333333332733
# Out:
# 1.33
# 1.333333250000001
# 1.3333333333332733

# %%
# 심파이를 사용해 적분 구하기

from sympy import *

# 심파이에 'x'를 선언합니다.
x = symbols('x')

# 파이썬 표현식을 사용해 함수를 정의합니다
f = x**2 + 1

# x=0과 1 사이의 면적을 구하기 위해
# x에 대해서 함수의 적분을 계산합니다.
area = integrate(f, (x, 0, 1))

print(area)
# Out:
# 4/3

# %%
# 극한을 사용해 적분 계산하기

from sympy import *

# 심파이에 변수를 선언
x, i, n = symbols('x i n')

# 함수와 범위를 선언
f = x**2 + 1
lower, upper = 0, 1

# 상자의 너비와 I 위치에 있는 직사각형의 높이를 계산합니다.
delta_x = ((upper - lower) / n)
x_i = (lower + delta_x * i)
fx_i = f.subs(x, x_i)

# n개의 직사각형을 순환하면서 면적을 더합니다.
n_rectangles = Sum(delta_x * fx_i, (i, 1, n)).doit()

# 직사각형의 개수 n을 무한대로 늘려 면적을 계산합니다.
area = limit(n_rectangles, n, oo)

print(area)
# Out:
# 4/3

# %%
# 오일러 수 미분
from sympy import *

x = symbols('x')
f = E**(2*x - 1)
dx_f = diff(f)
print(dx_f)
# Out:
# 2*exp(2*x - 1)

# %%
# f(x) = ln(x**2 - 1)의 도함수 구하기

from sympy import *

x = symbols('x')
f = log(x**2 - 1)

dx_f = diff(f)

print(dx_f)
# Out:
# 2*x/(x**2 - 1)

# %%
# 하나도 상환하지 않는다 가정
# 1_000 달러의 대출금에 연 5% 이자를 매월 복리로 적용하면 3년 후 갚아야 할 총 금액

p = 1000
r = 0.05
t = 3
n = 12

a = p * (1 + (r/n))**(n*t)

print(a)
# Out:
# 1161.4722313334678

# %%
# 하나도 상환하지 않는다 가정
# 1_000 달러의 대출금에 연속해서 연 5% 이자를 복리로 적용하면 3년 후 갚아야 할 총 금액
from math import exp

p = 1000
r = 0.05
t = 3

a = p * exp(r * t)

print(a)
# Out:
# 1161.834242728283

# %%
# x = 3에서 ƒ(x) = 3x**2 + 1 함수의 기울기 얼마인가요?

from sympy import *

x = symbols('x')
f = 3 * x**2 + 1

dx_f = diff(f)

print(dx_f.subs(x, 3))
# Out:
# 18

# %%
# 다음 두 함수가 있을 깨 연쇄 법칙을 사용해 x에 대한 z의 도함수를 구하세요

# y = x^3 - 1
# z = logy + 2

from sympy import *

x, y = symbols('x y')
_y  = x**3 - 1
z = log(y) + 2

dy_dx = diff(_y)
dz_dy = diff(z)

dz_dx = (dy_dx * dz_dy)
print(dz_dx.subs(y, (x**3 - 1)))
# Out:
# 3*x**2/(x**3 - 1)

# %%
# x가 0과 2 사이일 때 ƒ(x) = 3x^2 + 1 함수의 아래 면적은 얼마인가요?

from sympy import *
x = symbols('x')

f = 3 * x**2 + 1

area = integrate(f, (x, 0, 2))
print(area)
# Out:
# 10

# %%
# 파이선에서 베이즈 정리하기

p_coffee_drinker = 0.65
p_cancer = 0.005
p_coffee_drinker_given_cancer = 0.85

p_cancer_given_coffee_drinker = p_coffee_drinker_given_cancer * p_cancer / p_coffee_drinker

print(p_cancer_given_coffee_drinker)
# Out:
# 0.006538461538461539

# %%
# 사이파이를 사용해 이항 분포 계산하기

from scipy.stats import binom

n = 10
p = 0.9

for k in range(n+1):
    probability = binom.pmf(k, n, p)
    print("{0} - {1}".format(k, probability))
# Out:
# 0 - 9.999999999999977e-11
# 1 - 8.999999999999978e-09
# 2 - 3.6449999999999943e-07
# 3 - 8.747999999999991e-06
# 4 - 0.00013778099999999974
# 5 - 0.0014880347999999982
# 6 - 0.011160260999999996
# 7 - 0.05739562799999997
# 8 - 0.1937102444999998
# 9 - 0.38742048899999976
# 10 - 0.3486784401000001

# %%
# 사이파이를 사용한 베타 분포

from scipy.stats import beta

a = 8
b = 2

p = beta.cdf(0.90, a, b)

print(p)
# Out:
# 0.7748409780000002

# %%
from scipy.stats import binom

# passangers = 137
# p_no_show = 0.40

n = 137
p = 0.40

p_50_or_more_noshows = 0.0

for i in range(50, 138):
    p_50_or_more_noshows += binom.pmf(i, n, p)

print(p_50_or_more_noshows)
# Out:
# 0.8220955881474251

# %%
# 동전 19번 던짐. 앞면 15번 뒷면 4번 나옴 이 동전이 공정할 확률

from scipy.stats import beta

n = 19
f = 15
b = 4

p = 1.0 - beta.cdf(0.5, f, b)

print(p)
# Out:
# 0.9962310791015625

# %%
# 6번 문제에서 기준 확률이 0.7 ~ 0.8일 확률은 얼마인가?

from scipy.stats import beta

head = 15
tail = 4

p = (1.0 + beta.cdf(0.8, head, tail)) - (1.0 + beta.cdf(0.7, head, tail))

print(p)
# Out:
# 0.33647497661034365

# %%
# 평균 구하기

sample = [1, 3, 2, 5, 7, 0, 2, 3]

mean = sum(sample) / len(sample)
print(mean)
# Out:
# 2.875

# %%
# 가중 평균 구하기
# 세 시험의 가중치는 0.20이고 마지막 시험의 가중치는 0.40임

sample = [90, 80, 63, 87]
weights =[0.20, 0.20, 0.20, 0.40]

weighted_mean = sum(s * w for s, w in zip(sample, weights)) / sum(weights)

print(weighted_mean)
# Out:
# 81.4

# %%
# 중앙값 계산하기
# 각 사람이 소유한 반려동물의 수
sample = [0, 1, 5, 7, 9, 10, 14]

def median(values):
    ordered = sorted(values)
    print(ordered)
    n = len(ordered)

    mid = int(n/2) - 1 if n % 2 == 0 else int(n/2)

    if n % 2 == 0:
        return (ordered[mid] + ordered[mid + 1]) / 2.0

    else:
        return ordered[mid]

print(median(sample))
# Out:
# [0, 1, 5, 7, 9, 10, 14]
# 7

# %%
# 모드 계산하기
# 각 사람이 소유한 반려동물의 수

from collections import defaultdict

sample = [1, 3, 2, 5, 7, 0, 2, 3]

def mode(values):
    counts = defaultdict(lambda: 0)

    for s in values:
        counts[s] += 1

    max_count = max(counts.values())
    modes = [v for v in set(values) if counts[v] == max_count]

    return modes

print(mode(sample))
# Out:
# [2, 3]

# %%
# 모집단 표준편차 계산하기
from math import sqrt

data = [0, 1, 5, 7, 9, 10, 14]

def variance(values):
    mean = sum(data) / len(data)
    _variance = sum((v-mean)**2 for v in values) / len(values)

    return _variance

print(variance(data))

def std_dev(values):
    return sqrt(variance(values))

print(std_dev(data))
# Out:
# 21.387755102040817
# 4.62468973035390

# %%
# 표본의 표준편차 계산
from math import sqrt

# 각 사람이 소유한 반려동물의 수
data = [0, 1, 5, 7, 9, 10, 14]

def variance(values, is_sample: bool = False):
    mean = sum(values) / len(values)
    _variance = sum((v - mean)**2 for v in values) / (len(values) - (1 if is_sample else 0))

    return _variance

def std_def(values, is_sample: bool = False):
    return sqrt(variance(values, is_sample))

print("분산 = {}".format(variance(data, is_sample=True)))
print("표준편차 = {}".format(std_def(data, is_sample=True)))
# Out:
# 분산 = 24.952380952380953
# 표준편차 = 4.995235825502231

# %%
# 정규 분포 함수 만들기
# 정규 분포는 가능도를 반환함

def normal_pdf(x: float, mean: float, std_dev: float) -> float:
    return (1.0 / (2.0 * math.pi * std_dev ** 2) ** 0.5) * math.exp(-1.0 * ((x - mean) ** 2 / (2.0 * std_dev ** 2)))

# %%
# 정규 분포 cdf

from scipy.stats import norm

mean = 64.43
std_dev = 2.99

x = norm.cdf(66, mean, std_dev) - norm.cdf(62, mean, std_dev)

print(x)
# Out:
# 0.4920450147062894

# %%
# 역 CDF

from scipy.stats import norm

x = norm.ppf(0.95, loc = 64.43, scale = 2.99)
print(x)
# Out:
# 69.3481123445849

# %%
# 정규 분포에서 난수 생성하기

import random
from scipy.stats import norm

for i in range(1, 1000):
    random_p = random.uniform(0.0, 1.0)
    random_weight = norm.ppf(random_p, loc=64.43, scale = 2.99)
    print(random_weight)
# Out:
# 61.034484283544955
# 65.25125642707268
# 65.30874517787089
# 62.21350908985546
# 64.14888444318746
# 66.13433032126329
# 65.33985582148973
# 64.20727378627802
# 64.63412321622376
# 68.32509413783677
# 62.6409861261252
# 67.06770780037075
# 65.0746988493053
# 62.440831147339104
# 61.89945467811366
# 65.66518734947604
# 65.06139452327096
# 66.18709811620346
# 62.178908914166996
# 57.9082583385251
# 66.45773388866986
# 64.33305270110218
# 59.692425530032025
# 64.21855024193565
# 65.48743833450754
# 67.47852883639275
# 70.35663964529499
# 61.54770102461268
# 62.773173703005014
# 69.65156061751078
# 64.03942924078922
# 67.04264798631756
# 61.2610022825609
# 67.32025855885192
# 63.28376347473598
# 67.53303668919051
# 64.10369213983986
# 71.33867241245999
# 63.682196624791644
# 69.34160746099144
# 66.33487190522276
# 67.98714887494933
# 66.0676879132128
# 64.85622731098151
# 61.541129183499514
# 60.480210416237085
# 64.71163208090894
# 62.48876756039068
# 62.73283816556921
# ...

# %%
# z점수를 x값으로 또는 그 반대로 반환하기

def z_score(x, mean, std):
    return (x - mean) / std

def z_to_x(z, mean, std):
    return (z * std) + mean

mean = 140000
std_dev = 3000
x = 150000

# z 점수로 바꾸고 다시 x로 되돌리기
z = z_score(x, mean, std_dev)
back_to_x = z_to_x(z, mean, std_dev)

print("z 점수 {}".format(z))
print("x로 되돌리기 {}".format(back_to_x))

# %%
# 중심 극한 정리 실험하기

# 균등 분포에서 뽑은 표본의 평균은 정규 분포가 됩니다.

import random
import plotly.express as px

sample_size = 31
sample_count = 1000

# 중심 극한 정리, 크기가 31인 1000개의 표본
# 0.0 과 1.0 사이의 난수
x_values = [(sum([random.uniform(0.0, 1.0) for i in range(sample_size)]) /
             sample_size) for _ in range(sample_count)]

y_values = [1 for _ in range(sample_count)]

px.histogram(x=x_values, y = y_values, nbins = 20).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 임계 z값  검색

from scipy.stats import norm

def critical_z_value(p):
    norm_dist = norm(loc=0.0, scale=1.0)
    left_tail_area = (1.0 - p) / 2.0
    upper_area = 1.0 - ((1.0 - p) / 2.0)
    return norm_dist.ppf(left_tail_area), norm_dist.ppf(upper_area)

print(critical_z_value(p=0.95))
# Out:
# (np.float64(-1.959963984540054), np.float64(1.959963984540054))

# %%
# 신뢰 구간 계산하기

from math import sqrt
from scipy.stats import norm

def critical_z_value(p):
    norm_dist = norm(loc=0.0, scale=1.0)
    left_tail_area = (1.0 - p) / 2.0
    upper_area = 1.0 - ((1.0 - p) / 2.0)

    return norm_dist.ppf(left_tail_area), norm_dist.ppf(upper_area)

def confidence_interval(p, sample_mean, sample_std, n):
    lower, upper = critical_z_value(p)
    lower_ci = lower * (sample_std / sqrt(n))
    upper_ci = upper * (sample_std/ sqrt(n))

    return sample_mean +  lower_ci, sample_mean + upper_ci

print(confidence_interval(p=0.95, sample_mean=64.408, sample_std=2.05, n=31))
# Out:
# (np.float64(63.68635915701992), np.float64(65.12964084298008))

# %%
# 15일에서 21일 사이에 회복될 확률 계산하기

from scipy.stats import norm

# 감기의 회복 기간은 평균 18일이고 표준 편차는 1.5일입니다.
mean = 18
std_dev = 1.5

# 15일에서 21일 사이에 회복될 확률은 95%입니다.
x = norm.cdf(21, mean, std_dev) - norm.cdf(15, mean, std_dev)

print(x)
# Out:
# 0.9544997361036416

# %%
# 누적 면적 5%에 해당하는 x값을 계산함

from scipy.stats import norm

# 감기의 회복 기간은 평균 18일이고 표준 편차는 1.5일입니다.
mean = 18
std_dev = 1.5

# 누적 면적 5%에 해당하는 x 값은 얼마인가요?
x = norm.ppf(0.05, mean, std_dev)

print(x)
# Out:
# 15.53271955957279

# %%
# 단측 검정의 p값 계산하기

from scipy.stats import norm

# 감기의 회복 기간은 평균 18일이고 표준 편차가 1.5일입니다.
mean = 18
std_dev = 1.5

# 16보다 작거나 같을 확률
p_value = norm.cdf(16, mean, std_dev)

print(p_value)
# Out:
# 0.09121121972586788

# %%
# 통계적 유의성이 5%인 범위 계산하기
from scipy.stats import norm

# 감기의 회복 기간은 평균 18일이고 표준 편차가 1.5일입니다.
mean = 18
std_dev = 1.5

# 누적 면적 2.5%에 해당하는 x 값은 얼마인가요?
x1 = norm.ppf(0.025, mean, std_dev)

# 누적 면적 97.5%에 해당하는 x값은 얼마인가요?
x2 = norm.ppf(0.975, mean, std_dev)

print(x1)
print(x2)
# Out:
# 15.060054023189918
# 20.93994597681008

# %%
# 양측 검저의 p값 계산하기
from scipy.stats import norm

# 감기의 회복 기간은 평균 18일이고 표준 편차가 1.5일입니다.
mean = 18
std_dev = 1.5

# 16보다 작거나 같을 확률
p1 = norm.cdf(16, mean, std_dev)

# 20보다 크거나 같을 확률
p2 = 1.0 - norm.cdf(20, mean, std_dev)

# 양측 검정의 p값
p_value = p1 + p2

print(p_value)
# Out:
# 0.18242243945173575

# %%
# t 분포로 임곗값 범위 구하기
from scipy.stats import t

# 표본 크기가 25일 때
# 95% 신뢰도에 대한 임곗값 범위 구하기

n = 25
lower = t.ppf(0.025, df=n-1)
upper = t.ppf(0.975, df=n-1) # df(degree of freedom)자유도 매개변수: 표본 크기보다 하나 작아야 함

print(lower, upper)
# Out:
# -2.063898561628021 2.0638985616280205
